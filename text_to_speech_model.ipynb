# %%
# !pip install transformers
# !pip install gradio
# !pip install timm
# !pip install timm
# !pip install inflect
# !pip install phonemizer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/mikolaj/.local/lib/python3.10/site-packages (4.38.2)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /home/mikolaj/.local/lib/python3.10/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/mikolaj/.local/lib/python3.10/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers) (21.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/mikolaj/.local/lib/python3.10/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/mikolaj/.local/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: numpy>=1.17 in /home/mikolaj/.local/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: filelock in /home/mikolaj/.local/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gradio in /home/mikolaj/.local/lib/python3.10/site-packages (4.27.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (6.4.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.29.0)
# Requirement already satisfied: ffmpy in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.3.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/lib/python3/dist-packages (from gradio) (5.4.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: pydub in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: orjson~=3.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (3.10.1)
# Requirement already satisfied: matplotlib~=3.0 in /usr/lib/python3/dist-packages (from gradio) (3.5.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/lib/python3/dist-packages (from gradio) (9.0.1)
# Requirement already satisfied: pydantic>=2.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (2.7.0)
# Requirement already satisfied: fastapi in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.110.1)
# Requirement already satisfied: jinja2<4.0 in /usr/lib/python3/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy~=1.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: urllib3~=2.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (2.2.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.0.9)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from gradio) (21.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.12.3)
# Requirement already satisfied: tomlkit==0.12.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: httpx>=0.24.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.27.0)
# Requirement already satisfied: semantic-version~=2.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: ruff>=0.2.2 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.4.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (2.1.4)
# Requirement already satisfied: typing-extensions~=4.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (4.9.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.21.4)
# Requirement already satisfied: markupsafe~=2.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: gradio-client==0.15.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (0.15.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio) (5.3.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio-client==0.15.1->gradio) (11.0.3)
# Requirement already satisfied: fsspec in /home/mikolaj/.local/lib/python3.10/site-packages (from gradio-client==0.15.1->gradio) (2024.2.0)
# Requirement already satisfied: toolz in /home/mikolaj/.local/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: jsonschema>=3.0 in /usr/lib/python3/dist-packages (from altair<6.0,>=4.2.0->gradio) (3.2.0)
# Requirement already satisfied: httpcore==1.* in /home/mikolaj/.local/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: sniffio in /home/mikolaj/.local/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx>=0.24.1->gradio) (3.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.24.1->gradio) (2020.6.20)
# Requirement already satisfied: anyio in /home/mikolaj/.local/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (4.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/mikolaj/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.2)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from huggingface-hub>=0.19.3->gradio) (2.25.1)
# Requirement already satisfied: filelock in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mikolaj/.local/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas<3.0,>=1.0->gradio) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (2.18.1)
# Requirement already satisfied: rich>=10.11.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from typer<1.0,>=0.12->gradio) (8.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /home/mikolaj/.local/lib/python3.10/site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/mikolaj/.local/lib/python3.10/site-packages (from anyio->httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting timm
#   Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 5.0 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: torch in /home/mikolaj/.local/lib/python3.10/site-packages (from timm) (2.2.1)
# Requirement already satisfied: safetensors in /home/mikolaj/.local/lib/python3.10/site-packages (from timm) (0.4.2)
# Requirement already satisfied: huggingface_hub in /home/mikolaj/.local/lib/python3.10/site-packages (from timm) (0.21.4)
# Collecting torchvision
#   Downloading torchvision-0.17.2-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 10.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from timm) (5.4.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from huggingface_hub->timm) (2.25.1)
# Requirement already satisfied: filelock in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3/dist-packages (from huggingface_hub->timm) (21.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (2024.2.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (11.0.2.54)
# Requirement already satisfied: triton==2.2.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (2.2.0)
# Requirement already satisfied: networkx in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch->timm) (1.9)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (8.9.2.26)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch->timm) (3.0.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (10.3.2.106)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.0.106)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mikolaj/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm) (12.4.99)
# Collecting torch
#   Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:03
# Requirement already satisfied: numpy in /home/mikolaj/.local/lib/python3.10/site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/lib/python3/dist-packages (from torchvision->timm) (9.0.1)
# Installing collected packages: torch, torchvision, timm
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1
#     Uninstalling torch-2.2.1:
#       Successfully uninstalled torch-2.2.1
# Successfully installed timm-0.9.16 torch-2.2.2 torchvision-0.17.2
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: timm in /home/mikolaj/.local/lib/python3.10/site-packages (0.9.16)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from timm) (5.4.1)
# Requirement already satisfied: safetensors in /home/mikolaj/.local/lib/python3.10/site-packages (from timm) (0.4.2)
# Requirement already satisfied: torch in /home/mikolaj/.local/lib/python3.10/site-packages (from timm) (2.2.2)
# Requirement already satisfied: torchvision in /home/mikolaj/.local/lib/python3.10/site-packages (from timm) (0.17.2)
# Requirement already satisfied: huggingface_hub in /home/mikolaj/.local/lib/python3.10/site-packages (from timm) (0.21.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (4.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (2024.2.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (4.66.2)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3/dist-packages (from huggingface_hub->timm) (21.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from huggingface_hub->timm) (2.25.1)
# Requirement already satisfied: filelock in /home/mikolaj/.local/lib/python3.10/site-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (11.0.2.54)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.3.1)
# Requirement already satisfied: triton==2.2.0 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (2.2.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch->timm) (1.9)
# Requirement already satisfied: networkx in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (10.3.2.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (2.19.3)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mikolaj/.local/lib/python3.10/site-packages (from torch->timm) (11.4.5.107)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch->timm) (3.0.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mikolaj/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm) (12.4.99)
# Requirement already satisfied: numpy in /home/mikolaj/.local/lib/python3.10/site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/lib/python3/dist-packages (from torchvision->timm) (9.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting inflect
#   Downloading inflect-7.2.0-py3-none-any.whl (34 kB)
# Collecting typeguard>=4.0.1
#   Downloading typeguard-4.2.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: typing-extensions in /home/mikolaj/.local/lib/python3.10/site-packages (from inflect) (4.9.0)
# Requirement already satisfied: more-itertools in /usr/lib/python3/dist-packages (from inflect) (8.10.0)
# Collecting typing-extensions
#   Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Installing collected packages: typing-extensions, typeguard, inflect
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# Successfully installed inflect-7.2.0 typeguard-4.2.1 typing-extensions-4.11.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting phonemizer
#   Downloading phonemizer-3.2.1-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 KB 1.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /home/mikolaj/.local/lib/python3.10/site-packages (from phonemizer) (4.11.0)
# Collecting dlinfo
#   Downloading dlinfo-1.2.1-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: attrs>=18.1 in /usr/lib/python3/dist-packages (from phonemizer) (21.2.0)
# Collecting segments
#   Downloading segments-2.2.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: joblib in /home/mikolaj/.local/lib/python3.10/site-packages (from phonemizer) (1.3.2)
# Collecting csvw>=1.5.6
#   Downloading csvw-3.3.0-py2.py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: regex in /home/mikolaj/.local/lib/python3.10/site-packages (from segments->phonemizer) (2023.12.25)
# Collecting clldutils>=1.7.3
#   Downloading clldutils-3.22.2-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.9 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting colorlog
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 KB 10.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting bibtexparser>=2.0.0b4
#   Downloading bibtexparser-2.0.0b7-py3-none-any.whl (38 kB)
# Requirement already satisfied: markdown in /home/mikolaj/.local/lib/python3.10/site-packages (from clldutils>=1.7.3->segments->phonemizer) (3.5.1)
# Requirement already satisfied: markupsafe in /home/mikolaj/.local/lib/python3.10/site-packages (from clldutils>=1.7.3->segments->phonemizer) (2.1.3)
# Requirement already satisfied: python-dateutil in /home/mikolaj/.local/lib/python3.10/site-packages (from clldutils>=1.7.3->segments->phonemizer) (2.8.2)
# Requirement already satisfied: lxml in /usr/lib/python3/dist-packages (from clldutils>=1.7.3->segments->phonemizer) (4.8.0)
# Collecting language-tags
#   Downloading language_tags-1.2.0-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 KB 10.3 MB/s eta 0:00:00
# Collecting rdflib
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 KB 8.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from csvw>=1.5.6->segments->phonemizer) (2.25.1)
# Requirement already satisfied: jsonschema in /usr/lib/python3/dist-packages (from csvw>=1.5.6->segments->phonemizer) (3.2.0)
# Requirement already satisfied: babel in /usr/lib/python3/dist-packages (from csvw>=1.5.6->segments->phonemizer) (2.8.0)
# Collecting uritemplate>=3.0.0
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: colorama in /usr/lib/python3/dist-packages (from csvw>=1.5.6->segments->phonemizer) (0.4.4)
# Collecting rfc3986<2
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from isodate->csvw>=1.5.6->segments->phonemizer) (1.16.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/lib/python3/dist-packages (from rdflib->csvw>=1.5.6->segments->phonemizer) (2.4.7)
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136835 sha256=a495cb99aef7c6d5b4b767e8c3b8fa588531856b7c1d171f9d74b288e30c29e0
#   Stored in directory: /home/mikolaj/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# Installing collected packages: rfc3986, pylatexenc, language-tags, dlinfo, uritemplate, tabulate, isodate, colorlog, bibtexparser, rdflib, clldutils, csvw, segments, phonemizer
# Successfully installed bibtexparser-2.0.0b7 clldutils-3.22.2 colorlog-6.8.2 csvw-3.3.0 dlinfo-1.2.1 isodate-0.6.1 language-tags-1.2.0 phonemizer-3.2.1 pylatexenc-2.10 rdflib-7.0.0 rfc3986-1.5.0 segments-2.2.1 tabulate-0.9.0 uritemplate-4.1.1

# %%
from transformers.utils import logging

logging.set_verbosity_error()
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
from transformers import pipeline

narrator = pipeline("text-to-speech",
                    model="kakao-enterprise/vits-ljs")
# Out:
# 2024-04-20 16:23:08.009725: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-20 16:23:08.010039: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-20 16:23:08.130984: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-20 16:23:08.381675: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-20 16:23:09.693876: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# config.json:   0%|          | 0.00/1.64k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/145M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/285 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.14k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/47.0 [00:00<?, ?B/s]

# %%
text = """
Chrząszcz brzmi w trzcinie w Szczebrzeszynie,
W szczękach chrząszcza trzeszczy miąższ,
Czcza szczypawka czka w Szczecinie,
Chrząszcza szczudłem przechrzcił wąż.
"""

# %%
narrated_text = narrator(text)

# %%
from IPython.display import Audio as IPythonAudio

IPythonAudio(narrated_text["audio"][0],
             rate=narrated_text["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
